# %% [markdown]
# # Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
clean_data = pd.read_csv("Downloads/pds-assignment-master/Q1/data_clean/clean_frailty.csv")


# Scatter Plot Matrix
sns.pairplot(data, hue='Frailty', markers=["o", "s"])
plt.suptitle('Scatter Plot Matrix')
plt.show()

# %%
# Bar Plot of Frailty
sns.countplot(x='Frailty', data=data)
plt.title('Frailty Count')
plt.show()

# %%
# Histograms for numeric variables
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for i, col in enumerate(['Height', 'Weight', 'Age', 'Grip Strength']):
    sns.histplot(data[col], bins=10, kde=True, ax=axes[i // 2, i % 2])
    axes[i // 2, i % 2].set_title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# %%
# Box Plot for Grip Strength by Frailty
plt.figure(figsize=(8, 6))
sns.boxplot(x='Frailty', y='Grip Strength', data=data)
plt.title('Box Plot of Grip Strength by Frailty')
plt.show()

# %%
# Correlation Heatmap for numeric variables
correlation_matrix = data[['Height', 'Weight', 'Age', 'Grip Strength']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()
